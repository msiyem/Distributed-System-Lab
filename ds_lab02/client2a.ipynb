# %%
import socket
import threading
import time

# %%
HOST = "127.0.0.1"
PORT = 65004
N = 5  # number of "simultaneous" clients

# %%
def worker(i):
    with socket.socket(socket.AF_INET,socket.SOCK_STREAM) as s:
        s.connect((HOST,PORT))
        s.sendall(f"request - {i}".encode())

        reply = s.recv(1024).decode()
        print(f"[CLIENT {i}] {reply}")

# %%
def main():
    start = time.time()
    threads = [threading.Thread(
        target = worker,
        args = (i,)
    ) for i in range(N)]

    for t in threads:
        t.start()
    for t in threads:
        t.join()

    elapsed = time.time() - start

    print(f"\nAll {N} requests completed in {elapsed:.2f} seconds")
    print("(With MAX_WORKERS = 2 on the server, expect roughly 6s, not ~2s or ~10s)")

# %%
if __name__ == "__main__":
    main()
# Out:
# [CLIENT 1] Processed 'request - 1' by worker thread 129498119907008
# [CLIENT 0] Processed 'request - 0' by worker thread 129498128299712
# [CLIENT 2] Processed 'request - 2' by worker thread 129498111514304
# [CLIENT 3] Processed 'request - 3' by worker thread 129497626048192
# [CLIENT 4] Processed 'request - 4' by worker thread 129497617655488
#
# All 5 requests completed in 6.01 seconds
# (With MAX_WORKERS = 2 on the server, expect roughly 6s, not ~2s or ~10s)
