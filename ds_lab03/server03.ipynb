# %%
from xmlrpc.server import SimpleXMLRPCServer

# %%
host = "127.0.0.1"

# %%
port = 65003

# %%
def add(a,b):
    print(f"[Server] add ({a},{b}) called remotely")
    return a+b;

# %%
def factorial(n):
    print(f"[Server] factorial ({n}) called remotely")
    result = 1
    for i in range(2,n+1):
        result *= i
    return result

# %%
def reverse_string(s):
    print(f"[Server] reverse_string ({s!r}) called remotely")
    return s[::-1]

# %%
def main():
    server = SimpleXMLRPCServer((host,port),allow_none=True)
    server.register_function(add,"add")
    server.register_function(factorial,"factorial")
    server.register_function(reverse_string,"reverse_string")
    print(f"[SERVER] RPC server listening on {host}:{port}")
    print("[SERVER] Exposed procedures: add, factorial, reverse_string")
    server.serve_forever()

# %%
if __name__ == "__main__":
    main()
# Out:
# [SERVER] RPC server listening on 127.0.0.1:65003
# [SERVER] Exposed procedures: add, factorial, reverse_string
# [Server] add (4,7) called remotely
# [Server] factorial (5) called remotely
# [Server] reverse_string ('distributed') called remotely
# 127.0.0.1 - - [24/Sep/2026 00:00:24] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Sep/2026 00:00:24] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Sep/2026 00:00:24] "POST / HTTP/1.1" 200 -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[7], line 8, in main()
#       4     server.register_function(factorial,"factorial")
#       5     server.register_function(reverse_string,"reverse_string")
#       6     print(f"[SERVER] RPC server listening on {host}:{port}")
#       7     print("[SERVER] Exposed procedures: add, factorial, reverse_string")
# ----> 8     server.serve_forever()
#
# File ~/anaconda3/lib/python3.14/socketserver.py:235, in BaseServer.serve_forever(self, poll_interval)
#     232 selector.register(self, selectors.EVENT_READ)
#     234 while not self.__shutdown_request:
# --> 235     ready = selector.select(poll_interval)
#     236     # bpo-35017: shutdown() called during select(), exit immediately.
#     237     if self.__shutdown_request:
#
# File ~/anaconda3/lib/python3.14/selectors.py:398, in _PollLikeSelector.select(self, timeout)
#     396 ready = []
#     397 try:
# --> 398     fd_event_list = self._selector.poll(timeout)
#     399 except InterruptedError:
#     400     return ready
#
# KeyboardInterrupt:
